# %% [markdown]
# # Import Modules

# %%
import random 
import numpy as np
import tensorflow as tf
import os
import zipfile
import pathlib
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Downloading data from Kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6bdcc59c-efe7-4fd1-84b7-5fbfca26a868" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bdcc59c-efe7-4fd1-84b7-5fbfca26a868">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"andersonjustinpowa","key":"a38e40bfee29734fc4043809a9497f03"}'}

# %%
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# victorsoeiro/netflix-tv-shows-and-movies                     Netflix TV Shows and Movies                           2MB  2022-05-15 00:01:23           7206        220  1.0
# devansodariya/student-performance-data                       Student Performance Dataset                           7KB  2022-05-26 13:55:09           3066        125  0.9705882
# iamsouravbanerjee/software-professional-salaries-2022        Salary Dataset - 2022                               526KB  2022-06-10 06:02:59           1105         34  1.0
# paradisejoy/top-hits-spotify-from-20002019                   Top Hits Spotify from 2000-2019                      94KB  2022-05-31 07:20:57           5743        138  1.0
# surajjha101/stores-area-and-sales-data                       Supermarket store branches sales analysis            10KB  2022-04-29 11:10:16           6008        173  1.0
# mayureshkoli/police-deaths-in-usa-from-1791-to-2022          Police deaths in USA from 1791 to 2022              698KB  2022-06-09 17:47:57            333         23  1.0
# saddamazyazy/go-to-college-dataset                           Go To College Dataset                                12KB  2022-05-20 10:46:02           1151         32  1.0
# gunapro/student-behavior                                     Student Behavior                                      5KB  2022-06-03 13:45:54            815         34  0.7647059
# odins0n/amex-parquet                                         Amex Competition Data in Parquet Format               9GB  2022-05-25 23:20:19            749        101  1.0
# azminetoushikwasi/ucl-202122-uefa-champions-league           UCL ⚽ 2021-22 ⭐ Players Data | Champions League      55KB  2022-06-04 08:31:45           1067         42  1.0
# ahmedshahriarsakib/usa-real-estate-dataset                   USA Real Estate Dataset                               5MB  2022-06-04 21:40:25            747         30  1.0
# kkhandekar/cost-of-living-index-by-city-2022                 Cost of Living Index by City 2022                    15KB  2022-06-03 02:50:24            691         24  1.0
# ruchi798/parquet-files-amexdefault-prediction                Feather & Parquet Files : AMEX-Default Prediction    22GB  2022-05-26 05:46:53            551         83  1.0
# prasertk/cities-with-the-best-worklife-balance-2022          Cities with the Best Work-Life Balance 2022           5KB  2022-06-01 09:15:52            640         26  1.0
# kuchhbhi/play-store-apps-may2022                             Play Store Apps May-2022                            468KB  2022-05-19 07:57:19            680         25  1.0
# aryashah2k/sample-students-grades-dataset-tutorial-notebook  Sample Students Grades Dataset Tutorial Notebook     360B  2022-06-07 09:11:25            185         25  1.0
# dansbecker/melbourne-housing-snapshot                        Melbourne Housing Snapshot                          451KB  2018-06-05 12:52:24          88641       1084  0.7058824
# imoore/age-dataset                                           Age dataset: life, work, and death of 1.22M people   34MB  2022-06-07 08:56:52            268         33  1.0
# ankanhore545/dropout-or-academic-success                     Predict Dropout or Academic Success                 103KB  2022-06-05 11:32:43            334         23  0.9117647
# datasnaek/youtube-new                                        Trending YouTube Video Statistics                   201MB  2019-06-03 00:56:47         176774       4555  0.7941176

# %%
! kaggle datasets download -d sanikamal/horses-or-humans-dataset
# Out:
# Downloading horses-or-humans-dataset.zip to /content
# 100% 306M/307M [00:04<00:00, 46.6MB/s]
# 100% 307M/307M [00:04<00:00, 71.7MB/s]

# %% [markdown]
# # Reproducibility Function

# %%
! pip install tensorflow-determinism
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-determinism
#   Downloading tensorflow-determinism-0.3.0.tar.gz (12 kB)
# Building wheels for collected packages: tensorflow-determinism
#   Building wheel for tensorflow-determinism (setup.py) ... done
#   Created wheel for tensorflow-determinism: filename=tensorflow_determinism-0.3.0-py3-none-any.whl size=9158 sha256=a704b5db2fb18d8417805098a39848da2da5c174975fec4f4c720448ecdb4b0f
#   Stored in directory: /root/.cache/pip/wheels/d2/be/33/2b27e81e5d40b4bfb7c103ac6c6c5e81fdbcf40d2af5078529
# Successfully built tensorflow-determinism
# Installing collected packages: tensorflow-determinism
# Successfully installed tensorflow-determinism-0.3.0

# %%
def setup_seed(seed):
    random.seed(seed)  
    np.random.seed(seed) 
    tf.random.set_seed(seed)  # tf cpu fix seed
    os.environ['TF_DETERMINISTIC_OPS'] = '1'  # tf gpu fix seed, please `pip install tensorflow-determinism` first

# %% [markdown]
# # Get the data

# %%
# Unzip the downloaded file
zip_ref = zipfile.ZipFile("horses-or-humans-dataset.zip")
zip_ref.extractall()
zip_ref.close()

# %%
for dirpath, dirnames, filenames in os.walk("horse-or-human/horse-or-human"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in 'horse-or-human/horse-or-human'.
# There are 2 directories and 0 images in 'horse-or-human/horse-or-human/train'.
# There are 0 directories and 500 images in 'horse-or-human/horse-or-human/train/horses'.
# There are 0 directories and 527 images in 'horse-or-human/horse-or-human/train/humans'.
# There are 2 directories and 0 images in 'horse-or-human/horse-or-human/validation'.
# There are 0 directories and 128 images in 'horse-or-human/horse-or-human/validation/horses'.
# There are 0 directories and 128 images in 'horse-or-human/horse-or-human/validation/humans'.

# %%
# Create a function that can get the list of all class names in the datasets (can be either from train or validation dataset, but I will go with train datasets here)

def get_class_names(train_directory_path):
  data_dir = pathlib.Path(train_directory_path) # turning our training path into a Python Path
  class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
  return class_names

# %%
print(get_class_names("horse-or-human/horse-or-human/train"))
# Out:
# ['horses' 'humans']

# %% [markdown]
# There are total two classes in the dataset, namely horses and humans. For training datasets, we have 500 images for horses and 527 images for humans, while for validation datasets, we have 128 images for horses and 128 images for humans

# %%
# Let's visualize one of the pictures in train or validation datasets

# Create a function to visualize a random image from the train or validation datasets
def view_random_image(target_directory, class_name):
   
  # Setup the target directory
  target_folder = target_directory + "/" + class_name
  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1) # will output a string inside a list

  # Read the image and plot the image
  image = mpimg.imread(target_folder + "/" + random_image[0]) # random_image[0] will extract the string inside the list
  plt.imshow(image)
  plt.axis("off")

  print(f"Image shape: {image.shape}") # show the shape of the image

  return image

# %%
# View a random horse image from train dataset
horse_image = view_random_image(target_directory="horse-or-human/horse-or-human/train", 
                                class_name="horses")
# Out:
# Image shape: (300, 300, 4)

# %%
# View a random human image from train dataset
human_image = view_random_image(target_directory="horse-or-human/horse-or-human/train", 
                                class_name="humans")
# Out:
# Image shape: (300, 300, 4)

# %%
# Let's view the horse image
horse_image
# Out:
# array([[[0.69803923, 0.84705883, 1.        , 1.        ],
#         [0.69803923, 0.8509804 , 1.        , 1.        ],
#         [0.69803923, 0.8509804 , 1.        , 1.        ],
#         ...,
#         [0.61960787, 0.7647059 , 0.95686275, 1.        ],
#         [0.62352943, 0.7647059 , 0.95686275, 1.        ],
#         [0.62352943, 0.7647059 , 0.9607843 , 1.        ]],
#
#        [[0.69803923, 0.84705883, 1.        , 1.        ],
#         [0.69803923, 0.84705883, 1.        , 1.        ],
#         [0.69803923, 0.84705883, 1.        , 1.        ],
#         ...,
#         [0.6156863 , 0.7647059 , 0.95686275, 1.        ],
#         [0.61960787, 0.7647059 , 0.95686275, 1.        ],
#         [0.61960787, 0.7647059 , 0.95686275, 1.        ]],
#
#        [[0.69803923, 0.84313726, 1.        , 1.        ],
#         [0.69803923, 0.84313726, 1.        , 1.        ],
#         [0.69411767, 0.84313726, 1.        , 1.        ],
#         ...,
#         [0.6156863 , 0.7647059 , 0.95686275, 1.        ],
#         [0.6156863 , 0.7647059 , 0.95686275, 1.        ],
#         [0.6156863 , 0.7647059 , 0.95686275, 1.        ]],
#
#        ...,
#
#        [[0.29411766, 0.23137255, 0.18431373, 1.        ],
#         [0.27450982, 0.21568628, 0.17254902, 1.        ],
#         [0.30980393, 0.24705882, 0.2       , 1.        ],
#         ...,
#         [0.6784314 , 0.5686275 , 0.46666667, 1.        ],
#         [0.67058825, 0.5647059 , 0.46666667, 1.        ],
#         [0.6745098 , 0.5686275 , 0.4745098 , 1.        ]],
#
#        [[0.3137255 , 0.2509804 , 0.2       , 1.        ],
#         [0.3137255 , 0.2509804 , 0.20392157, 1.        ],
#         [0.28235295, 0.22745098, 0.18039216, 1.        ],
#         ...,
#         [0.7254902 , 0.6117647 , 0.49803922, 1.        ],
#         [0.70980394, 0.59607846, 0.49411765, 1.        ],
#         [0.7137255 , 0.6039216 , 0.49803922, 1.        ]],
#
#        [[0.31764707, 0.25490198, 0.20392157, 1.        ],
#         [0.30588236, 0.24313726, 0.19607843, 1.        ],
#         [0.3137255 , 0.2509804 , 0.20392157, 1.        ],
#         ...,
#         [0.7294118 , 0.6156863 , 0.5058824 , 1.        ],
#         [0.74509805, 0.63529414, 0.52156866, 1.        ],
#         [0.7529412 , 0.6431373 , 0.5294118 , 1.        ]]], dtype=float32)

# %% [markdown]
# **Note:** Since the image is already normalized to have a value between zero and one, further division by 255 is no longer needed

# %% [markdown]
# # Build the model from scratch

# %% [markdown]
# **First Experiment** (10 epochs): From the results obtained in the first experiment, it looks like our model is **overfitting** as the validation loss is in increasing trend. To ensure that the model is really overfitting, let's increase the epochs to 30.
#
# **Second Experiment** (30 epochs): It is clear that now the model is overfitting as the validation loss and the training loss is quite large. In addition, the validation loss is in increasing trend. As a result, we will try to use another method, which is **data augmentation**, to reduce the overfitting.

# %%
setup_seed(42)

train_datagen = ImageDataGenerator()
validation_datagen = ImageDataGenerator()

# Setup the train and validation directories
train_directory = "horse-or-human/horse-or-human/train/"
validation_directory = "horse-or-human/horse-or-human/validation/"

# Import data from the directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_directory,
                                               batch_size=32, 
                                               target_size=(300, 300),
                                               color_mode="rgba",
                                               class_mode="binary", # since we are dealing with binary classification
                                               seed=42) 

validation_data = validation_datagen.flow_from_directory(validation_directory,
                                               batch_size=32, 
                                               target_size=(300, 300), 
                                               color_mode="rgba",
                                               class_mode="binary", # since we are dealing with binary classification
                                               seed=42) 

# Create a CNN model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu", input_shape=(300, 300, 4)),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Flatten(), 
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_1.compile(loss="binary_crossentropy", 
                optimizer=tf.keras.optimizers.Adam(), 
                metrics=['accuracy'])

# Fit the model
history_1 = model_1.fit(train_data, 
                        epochs=30, 
                        steps_per_epoch=len(train_data), 
                        validation_data=validation_data, 
                        validation_steps=len(validation_data))
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Epoch 1/30
# 33/33 [==============================] - 13s 383ms/step - loss: 1.8124 - accuracy: 0.7030 - val_loss: 0.6400 - val_accuracy: 0.7422
# Epoch 2/30
# 33/33 [==============================] - 13s 390ms/step - loss: 0.1897 - accuracy: 0.9328 - val_loss: 1.1436 - val_accuracy: 0.7891
# Epoch 3/30
# 33/33 [==============================] - 13s 378ms/step - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.9086 - val_accuracy: 0.8359
# Epoch 4/30
# 33/33 [==============================] - 12s 376ms/step - loss: 0.0273 - accuracy: 0.9912 - val_loss: 1.0880 - val_accuracy: 0.8516
# Epoch 5/30
# 33/33 [==============================] - 13s 384ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 1.3307 - val_accuracy: 0.8398
# Epoch 6/30
# 33/33 [==============================] - 12s 375ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.4717 - val_accuracy: 0.8359
# Epoch 7/30
# 33/33 [==============================] - 13s 377ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.4309 - val_accuracy: 0.8438
# Epoch 8/30
# 33/33 [==============================] - 12s 386ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.8330 - val_accuracy: 0.8242
# Epoch 9/30
# 33/33 [==============================] - 13s 391ms/step - loss: 0.0582 - accuracy: 0.9776 - val_loss: 0.7223 - val_accuracy: 0.9023
# Epoch 10/30
# 33/33 [==============================] - 13s 377ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 1.0214 - val_accuracy: 0.8594
# Epoch 11/30
# 33/33 [==============================] - 12s 376ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.4303 - val_accuracy: 0.8516
# Epoch 12/30
# 33/33 [==============================] - 12s 378ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.6717 - val_accuracy: 0.8438
# Epoch 13/30
# 33/33 [==============================] - 12s 374ms/step - loss: 7.8582e-04 - accuracy: 1.0000 - val_loss: 1.7990 - val_accuracy: 0.8438
# Epoch 14/30
# 33/33 [==============================] - 13s 376ms/step - loss: 5.4700e-04 - accuracy: 1.0000 - val_loss: 1.7468 - val_accuracy: 0.8516
# Epoch 15/30
# 33/33 [==============================] - 13s 379ms/step - loss: 4.2781e-04 - accuracy: 1.0000 - val_loss: 1.7879 - val_accuracy: 0.8516
# Epoch 16/30
# 33/33 [==============================] - 12s 378ms/step - loss: 3.2414e-04 - accuracy: 1.0000 - val_loss: 1.8861 - val_accuracy: 0.8516
# Epoch 17/30
# 33/33 [==============================] - 13s 386ms/step - loss: 2.7027e-04 - accuracy: 1.0000 - val_loss: 1.9059 - val_accuracy: 0.8516
# Epoch 18/30
# 33/33 [==============================] - 13s 385ms/step - loss: 2.3027e-04 - accuracy: 1.0000 - val_loss: 1.9480 - val_accuracy: 0.8516
# Epoch 19/30
# 33/33 [==============================] - 13s 375ms/step - loss: 2.0952e-04 - accuracy: 1.0000 - val_loss: 1.9533 - val_accuracy: 0.8516
# Epoch 20/30
# 33/33 [==============================] - 12s 377ms/step - loss: 1.8117e-04 - accuracy: 1.0000 - val_loss: 2.0365 - val_accuracy: 0.8516
# Epoch 21/30
# 33/33 [==============================] - 13s 378ms/step - loss: 1.6092e-04 - accuracy: 1.0000 - val_loss: 2.0047 - val_accuracy: 0.8516
# Epoch 22/30
# 33/33 [==============================] - 12s 379ms/step - loss: 1.7647e-04 - accuracy: 1.0000 - val_loss: 1.7400 - val_accuracy: 0.8672
# Epoch 23/30
# 33/33 [==============================] - 13s 376ms/step - loss: 1.5509e-04 - accuracy: 1.0000 - val_loss: 2.0151 - val_accuracy: 0.8516
# Epoch 24/30
# 33/33 [==============================] - 13s 379ms/step - loss: 1.1123e-04 - accuracy: 1.0000 - val_loss: 2.0414 - val_accuracy: 0.8516
# Epoch 25/30
# 33/33 [==============================] - 13s 380ms/step - loss: 9.7703e-05 - accuracy: 1.0000 - val_loss: 2.1007 - val_accuracy: 0.8516
# Epoch 26/30
# 33/33 [==============================] - 13s 380ms/step - loss: 8.8590e-05 - accuracy: 1.0000 - val_loss: 2.1282 - val_accuracy: 0.8516
# Epoch 27/30
# 33/33 [==============================] - 13s 383ms/step - loss: 8.0026e-05 - accuracy: 1.0000 - val_loss: 2.1771 - val_accuracy: 0.8516
# Epoch 28/30
# 33/33 [==============================] - 13s 376ms/step - loss: 7.4110e-05 - accuracy: 1.0000 - val_loss: 2.1997 - val_accuracy: 0.8516
# Epoch 29/30
# 33/33 [==============================] - 12s 378ms/step - loss: 6.8856e-05 - accuracy: 1.0000 - val_loss: 2.2398 - val_accuracy: 0.8516
# Epoch 30/30
# 33/33 [==============================] - 13s 386ms/step - loss: 6.4548e-05 - accuracy: 1.0000 - val_loss: 2.2255 - val_accuracy: 0.8516

# %%
# Create a function to plot the training curves

def plot_training_curve(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
# Plot the training curve for model_1
plot_training_curve(history_1)

# %%
model_1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 298, 298, 10)      370
#
#  conv2d_19 (Conv2D)          (None, 296, 296, 10)      910
#
#  max_pooling2d_9 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 146, 146, 10)      910
#
#  conv2d_21 (Conv2D)          (None, 144, 144, 10)      910
#
#  max_pooling2d_10 (MaxPoolin  (None, 72, 72, 10)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 70, 70, 10)        910
#
#  conv2d_23 (Conv2D)          (None, 68, 68, 10)        910
#
#  max_pooling2d_11 (MaxPoolin  (None, 34, 34, 10)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 11560)             0
#
#  dense_3 (Dense)             (None, 1)                 11561
#
# =================================================================
# Total params: 16,481
# Trainable params: 16,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Build our model from scratch (using data augmentation)

# %% [markdown]
# As model_1 is overfitting, in this section, we will try to reduce the overfitting by using data augmentation
#
# **First Experiment** (10 epochs): Looks like the model is overfitting as the validation loss is not in decreasing trend. Let's increase the epoch to 30 to ensure that the model is really overfitting.
#
# **Second Experiment** (30 epochs): Now it is clear that the model's validation loss is in increasing trend. We will try to another method, which utilizes both **data augmentation** and Keras **Dropout layers** to reduce overfitting

# %%
setup_seed(42)

# Create ImageDataGenerator training instance with data augmentation
train_datagen_augmented = ImageDataGenerator(rotation_range=20, # rotate the image slightly between 0 and 20 degrees (note: this is an int not a float)
                                             shear_range=1, # shear the image
                                             zoom_range=1, # zoom into the image
                                             width_shift_range=1, # shift the image width ways
                                             height_shift_range=1, # shift the image height ways
                                             horizontal_flip=True) # flip the image on the horizontal axis
                                             
validation_datagen = ImageDataGenerator()

# Setup the train and validation directories
train_directory = "horse-or-human/horse-or-human/train/"
validation_directory = "horse-or-human/horse-or-human/validation/"

# Import data from the directories and turn it into batches
train_data_augmented = train_datagen_augmented.flow_from_directory(train_directory,
                                                                   batch_size=32, 
                                                                   target_size=(300, 300),
                                                                   color_mode="rgba", 
                                                                   class_mode="binary", # since we are dealing with binary classification
                                                                   shuffle=True,
                                                                   seed=42)
                                                  

validation_data = validation_datagen.flow_from_directory(validation_directory,
                                               batch_size=32, 
                                               target_size=(300, 300),
                                               color_mode="rgba", 
                                               class_mode="binary", # since we are dealing with binary classification
                                               seed=42) 

# Create a CNN model
model_2 = tf.keras.Sequential([
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu", input_shape=(300, 300, 4)),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Flatten(), 
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_2.compile(loss="binary_crossentropy", 
                optimizer=tf.keras.optimizers.Adam(), 
                metrics=['accuracy'])

# Fit the model
history_2 = model_2.fit(train_data_augmented, 
                        epochs=30, 
                        steps_per_epoch=len(train_data_augmented), 
                        validation_data=validation_data, 
                        validation_steps=len(validation_data))
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Epoch 1/30
# 33/33 [==============================] - 35s 1s/step - loss: 1.6927 - accuracy: 0.5725 - val_loss: 0.3839 - val_accuracy: 0.8789
# Epoch 2/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.5460 - accuracy: 0.7264 - val_loss: 0.4084 - val_accuracy: 0.8047
# Epoch 3/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.4805 - accuracy: 0.7722 - val_loss: 0.5180 - val_accuracy: 0.7539
# Epoch 4/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.4464 - accuracy: 0.7858 - val_loss: 1.1561 - val_accuracy: 0.6328
# Epoch 5/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.4266 - accuracy: 0.7955 - val_loss: 0.3362 - val_accuracy: 0.8672
# Epoch 6/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3817 - accuracy: 0.8238 - val_loss: 1.2212 - val_accuracy: 0.6172
# Epoch 7/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3361 - accuracy: 0.8481 - val_loss: 0.6751 - val_accuracy: 0.7578
# Epoch 8/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3801 - accuracy: 0.8296 - val_loss: 1.1610 - val_accuracy: 0.5703
# Epoch 9/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3482 - accuracy: 0.8500 - val_loss: 0.5995 - val_accuracy: 0.7227
# Epoch 10/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3040 - accuracy: 0.8695 - val_loss: 0.7517 - val_accuracy: 0.7344
# Epoch 11/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2730 - accuracy: 0.8754 - val_loss: 0.5752 - val_accuracy: 0.8008
# Epoch 12/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2992 - accuracy: 0.8861 - val_loss: 1.0945 - val_accuracy: 0.6445
# Epoch 13/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2899 - accuracy: 0.8880 - val_loss: 0.9792 - val_accuracy: 0.6797
# Epoch 14/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2529 - accuracy: 0.8958 - val_loss: 0.3186 - val_accuracy: 0.8789
# Epoch 15/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2702 - accuracy: 0.8861 - val_loss: 0.8044 - val_accuracy: 0.7461
# Epoch 16/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2440 - accuracy: 0.8997 - val_loss: 1.5176 - val_accuracy: 0.6484
# Epoch 17/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2403 - accuracy: 0.9036 - val_loss: 0.9079 - val_accuracy: 0.7422
# Epoch 18/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2294 - accuracy: 0.8929 - val_loss: 1.3061 - val_accuracy: 0.6680
# Epoch 19/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2202 - accuracy: 0.9192 - val_loss: 0.7788 - val_accuracy: 0.7227
# Epoch 20/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2333 - accuracy: 0.8978 - val_loss: 0.5716 - val_accuracy: 0.7773
# Epoch 21/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2201 - accuracy: 0.9114 - val_loss: 1.0816 - val_accuracy: 0.7031
# Epoch 22/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2378 - accuracy: 0.9211 - val_loss: 1.1595 - val_accuracy: 0.6445
# Epoch 23/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3438 - accuracy: 0.8452 - val_loss: 0.7190 - val_accuracy: 0.7773
# Epoch 24/30
# 33/33 [==============================] - 35s 1s/step - loss: 0.2945 - accuracy: 0.8734 - val_loss: 1.0537 - val_accuracy: 0.7148
# Epoch 25/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2742 - accuracy: 0.8832 - val_loss: 1.0406 - val_accuracy: 0.7070
# Epoch 26/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.3148 - accuracy: 0.8647 - val_loss: 1.1027 - val_accuracy: 0.6484
# Epoch 27/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2540 - accuracy: 0.8968 - val_loss: 0.6877 - val_accuracy: 0.7891
# Epoch 28/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2356 - accuracy: 0.9046 - val_loss: 2.1994 - val_accuracy: 0.5547
# Epoch 29/30
# 33/33 [==============================] - 34s 1s/step - loss: 0.2634 - accuracy: 0.8861 - val_loss: 1.0499 - val_accuracy: 0.6914
# Epoch 30/30
# 33/33 [==============================] - 35s 1s/step - loss: 0.2272 - accuracy: 0.9065 - val_loss: 1.3206 - val_accuracy: 0.6602

# %%
# Plot the training curve for model_2
plot_training_curve(history_2)

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 298, 298, 10)      370
#
#  conv2d_7 (Conv2D)           (None, 296, 296, 10)      910
#
#  max_pooling2d_3 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 146, 146, 10)      910
#
#  conv2d_9 (Conv2D)           (None, 144, 144, 10)      910
#
#  max_pooling2d_4 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 70, 70, 10)        910
#
#  conv2d_11 (Conv2D)          (None, 68, 68, 10)        910
#
#  max_pooling2d_5 (MaxPooling  (None, 34, 34, 10)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 11560)             0
#
#  dense_1 (Dense)             (None, 1)                 11561
#
# =================================================================
# Total params: 16,481
# Trainable params: 16,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Build our model from scratch (adding Dropout layer + data augmentation)

# %% [markdown]
# **First Experiment** (10 epochs, 0.3 dropout rate): The loss and the accuracy for both tranining set and validation set are in right direction (except for the last epoch where the validation loss increase a little, indicating that there is a slight overfitting). Let's train the model longer by increasing the epoch to 30
#
# **Second Experiment** (30 epochs, 0.3 dropout rate): Looks like the model's training and validation loss starts to decrease, although there are quite a number of fluctuations in the loss graph. In addition, the accuracy for both training and validation set starts to increase. Let's train the model longer to see whether we can bring down the loss more and increase the accuracy
#
# **Third Experiment** (50 epochs, 0.3 dropout rate): It turns out the model starts to overfit if we train more than 30 epochs. It can be seen that the model's validation curve is generally increasing, while the model's validaiton accuracy is generally decreasing. So we will stop the training once we have trained the model for 30 epochs.

# %%
setup_seed(42)

# Create ImageDataGenerator training instance with data augmentation
train_datagen_augmented = ImageDataGenerator(rotation_range=20, # rotate the image slightly between 0 and 20 degrees (note: this is an int not a float)
                                             shear_range=1, # shear the image
                                             zoom_range=1, # zoom into the image
                                             width_shift_range=1, # shift the image width ways
                                             height_shift_range=1, # shift the image height ways
                                             horizontal_flip=True) # flip the image on the horizontal axis
                                             
validation_datagen = ImageDataGenerator()

# Setup the train and validation directories
train_directory = "horse-or-human/horse-or-human/train/"
validation_directory = "horse-or-human/horse-or-human/validation/"

# Import data from the directories and turn it into batches
train_data_augmented = train_datagen_augmented.flow_from_directory(train_directory,
                                                                   batch_size=32, 
                                                                   target_size=(300, 300), 
                                                                   color_mode="rgba",
                                                                   class_mode="binary", # since we are dealing with binary classification
                                                                   shuffle=True,
                                                                   seed=42)
                                                  

validation_data = validation_datagen.flow_from_directory(validation_directory,
                                               batch_size=32, 
                                               target_size=(300, 300),  
                                               color_mode="rgba",
                                               class_mode="binary", # since we are dealing with binary classification
                                               seed=42) 

# Create a CNN model
model_3 = tf.keras.Sequential([
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu", input_shape=(300, 300, 4)),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"),
  tf.keras.layers.Conv2D(filters=10, kernel_size=3, activation="relu"), 
  tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
  tf.keras.layers.Dropout(0.3),
  tf.keras.layers.Flatten(), 
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_3.compile(loss="binary_crossentropy", 
                optimizer=tf.keras.optimizers.Adam(), 
                metrics=['accuracy'])

# Fit the model
history_3 = model_3.fit(train_data_augmented, 
                        epochs=50, 
                        steps_per_epoch=len(train_data_augmented), 
                        validation_data=validation_data, 
                        validation_steps=len(validation_data))
# Out:
# Found 1027 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Epoch 1/50
# 33/33 [==============================] - 35s 1s/step - loss: 7.1255 - accuracy: 0.5054 - val_loss: 0.7168 - val_accuracy: 0.5078
# Epoch 2/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.7416 - accuracy: 0.4479 - val_loss: 0.6839 - val_accuracy: 0.5859
# Epoch 3/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.6842 - accuracy: 0.5540 - val_loss: 0.6756 - val_accuracy: 0.6016
# Epoch 4/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.6704 - accuracy: 0.5852 - val_loss: 0.6749 - val_accuracy: 0.5938
# Epoch 5/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.6789 - accuracy: 0.5511 - val_loss: 0.6674 - val_accuracy: 0.5898
# Epoch 6/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.6593 - accuracy: 0.5940 - val_loss: 0.6482 - val_accuracy: 0.6055
# Epoch 7/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.6242 - accuracy: 0.6504 - val_loss: 0.6145 - val_accuracy: 0.6641
# Epoch 8/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.5843 - accuracy: 0.6913 - val_loss: 0.5859 - val_accuracy: 0.7031
# Epoch 9/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.5346 - accuracy: 0.7352 - val_loss: 0.5933 - val_accuracy: 0.6719
# Epoch 10/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4881 - accuracy: 0.7692 - val_loss: 0.6202 - val_accuracy: 0.6289
# Epoch 11/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4685 - accuracy: 0.7819 - val_loss: 0.6681 - val_accuracy: 0.6484
# Epoch 12/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4393 - accuracy: 0.7975 - val_loss: 0.6451 - val_accuracy: 0.6523
# Epoch 13/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4746 - accuracy: 0.7809 - val_loss: 0.6621 - val_accuracy: 0.6328
# Epoch 14/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4454 - accuracy: 0.7858 - val_loss: 0.7679 - val_accuracy: 0.6133
# Epoch 15/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4397 - accuracy: 0.8004 - val_loss: 0.7059 - val_accuracy: 0.6016
# Epoch 16/50
# 33/33 [==============================] - 35s 1s/step - loss: 0.4170 - accuracy: 0.8101 - val_loss: 0.6941 - val_accuracy: 0.6328
# Epoch 17/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3939 - accuracy: 0.8296 - val_loss: 0.6443 - val_accuracy: 0.6680
# Epoch 18/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4169 - accuracy: 0.8160 - val_loss: 0.6445 - val_accuracy: 0.6445
# Epoch 19/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3946 - accuracy: 0.8208 - val_loss: 0.7554 - val_accuracy: 0.6250
# Epoch 20/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3709 - accuracy: 0.8267 - val_loss: 0.6794 - val_accuracy: 0.6328
# Epoch 21/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3437 - accuracy: 0.8423 - val_loss: 0.5865 - val_accuracy: 0.6797
# Epoch 22/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3312 - accuracy: 0.8471 - val_loss: 0.5744 - val_accuracy: 0.6914
# Epoch 23/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3346 - accuracy: 0.8530 - val_loss: 0.4524 - val_accuracy: 0.7930
# Epoch 24/50
# 33/33 [==============================] - 35s 1s/step - loss: 0.4067 - accuracy: 0.8121 - val_loss: 0.6011 - val_accuracy: 0.7188
# Epoch 25/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3952 - accuracy: 0.8306 - val_loss: 0.7663 - val_accuracy: 0.6445
# Epoch 26/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4175 - accuracy: 0.8189 - val_loss: 0.5331 - val_accuracy: 0.7305
# Epoch 27/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3815 - accuracy: 0.8228 - val_loss: 0.4875 - val_accuracy: 0.7734
# Epoch 28/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3609 - accuracy: 0.8345 - val_loss: 0.8558 - val_accuracy: 0.6289
# Epoch 29/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3814 - accuracy: 0.8277 - val_loss: 0.4612 - val_accuracy: 0.7734
# Epoch 30/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3071 - accuracy: 0.8676 - val_loss: 0.2957 - val_accuracy: 0.9336
# Epoch 31/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3299 - accuracy: 0.8647 - val_loss: 0.4577 - val_accuracy: 0.7656
# Epoch 32/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3224 - accuracy: 0.8569 - val_loss: 0.3812 - val_accuracy: 0.8242
# Epoch 33/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3219 - accuracy: 0.8539 - val_loss: 0.3396 - val_accuracy: 0.8594
# Epoch 34/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3219 - accuracy: 0.8685 - val_loss: 0.4515 - val_accuracy: 0.7891
# Epoch 35/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3228 - accuracy: 0.8617 - val_loss: 0.3203 - val_accuracy: 0.8711
# Epoch 36/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3080 - accuracy: 0.8695 - val_loss: 0.4997 - val_accuracy: 0.7500
# Epoch 37/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3339 - accuracy: 0.8393 - val_loss: 0.6206 - val_accuracy: 0.6836
# Epoch 38/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.4004 - accuracy: 0.8296 - val_loss: 0.3897 - val_accuracy: 0.8125
# Epoch 39/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.3228 - accuracy: 0.8617 - val_loss: 0.4731 - val_accuracy: 0.7617
# Epoch 40/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2900 - accuracy: 0.8851 - val_loss: 0.5047 - val_accuracy: 0.7617
# Epoch 41/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2665 - accuracy: 0.8929 - val_loss: 0.6977 - val_accuracy: 0.7227
# Epoch 42/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3294 - accuracy: 0.8647 - val_loss: 0.4920 - val_accuracy: 0.7656
# Epoch 43/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.2891 - accuracy: 0.8890 - val_loss: 0.8490 - val_accuracy: 0.6758
# Epoch 44/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.2748 - accuracy: 0.8958 - val_loss: 0.5933 - val_accuracy: 0.7383
# Epoch 45/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2535 - accuracy: 0.8919 - val_loss: 0.5426 - val_accuracy: 0.7852
# Epoch 46/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2879 - accuracy: 0.8744 - val_loss: 0.6010 - val_accuracy: 0.7500
# Epoch 47/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2943 - accuracy: 0.8685 - val_loss: 0.9946 - val_accuracy: 0.6016
# Epoch 48/50
# 33/33 [==============================] - 33s 1s/step - loss: 0.2715 - accuracy: 0.8939 - val_loss: 0.6587 - val_accuracy: 0.7422
# Epoch 49/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.3091 - accuracy: 0.8656 - val_loss: 0.7564 - val_accuracy: 0.6562
# Epoch 50/50
# 33/33 [==============================] - 34s 1s/step - loss: 0.2653 - accuracy: 0.8744 - val_loss: 0.9239 - val_accuracy: 0.6250

# %%
# Plot the training curve for model_3
plot_training_curve(history_3)

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 298, 298, 10)      370
#
#  conv2d_13 (Conv2D)          (None, 296, 296, 10)      910
#
#  max_pooling2d_6 (MaxPooling  (None, 148, 148, 10)     0
#  2D)
#
#  dropout_3 (Dropout)         (None, 148, 148, 10)      0
#
#  conv2d_14 (Conv2D)          (None, 146, 146, 10)      910
#
#  conv2d_15 (Conv2D)          (None, 144, 144, 10)      910
#
#  max_pooling2d_7 (MaxPooling  (None, 72, 72, 10)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 72, 72, 10)        0
#
#  conv2d_16 (Conv2D)          (None, 70, 70, 10)        910
#
#  conv2d_17 (Conv2D)          (None, 68, 68, 10)        910
#
#  max_pooling2d_8 (MaxPooling  (None, 34, 34, 10)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 34, 34, 10)        0
#
#  flatten_2 (Flatten)         (None, 11560)             0
#
#  dense_2 (Dense)             (None, 1)                 11561
#
# =================================================================
# Total params: 16,481
# Trainable params: 16,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note: It looks like `model_3` performs the best compared to the other model that have been built so far, with ~86% accuracy in train dataset and ~93% accuracy in validation dataset. Another method that can be used to solve overfitting problem aside from using data augmentation and adding dropout layer is by using **transfer learning**
